# %%
# Instalar Optuna (Solo necesario la primera vez)
# !pip install optuna xgboost scikit-learn polars

import optuna
import xgboost as xgb
import polars as pl
import numpy as np
import os
import gc
import json

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score

# --- CONFIGURACIÓN ---
MASTER_FILE = "draft_oracle_master_data.parquet"
FEATURE_FILE = "draft_oracle_feature_store.parquet"
TRAIN_SET_FILE = "draft_oracle_training_set.parquet" # Archivo temporal
MODEL_FILE = "draft_oracle_brain_optuna.json" # MODELO FINAL OPTIMIZADO

print("✅ Entorno listo con Optuna (AutoML).")
# Out:
# ✅ Entorno listo con Optuna (AutoML).

# %% [markdown]
# Ensamblaje de la data

# %%
# 1. DEFINICIÓN DE LÓGICA V12 (EXACTAMENTE IGUAL A ML2)
def enrich_combat_logic(df):
    print("🧠 Calculando Lógica de Combate...")
    sides = ["blue", "red"]
    for side in sides:
        magic_cols = [c for c in df.columns if f"{side}_" in c and ("stat_magic_dmg" in c or "avg_magic_dmg" in c)]
        phys_cols  = [c for c in df.columns if f"{side}_" in c and ("stat_phys_dmg" in c or "avg_phys_dmg" in c)]
        true_cols  = [c for c in df.columns if f"{side}_" in c and ("stat_true_dmg" in c or "avg_true_dmg" in c)]
        tank_cols  = [c for c in df.columns if f"{side}_" in c and "stat_mitigated" in c]
        heal_cols  = [c for c in df.columns if f"{side}_" in c and "stat_heal" in c]
        cc_cols    = [c for c in df.columns if f"{side}_" in c and "stat_hard_cc" in c]

        total_magic = pl.sum_horizontal(magic_cols) if magic_cols else pl.lit(0)
        total_phys  = pl.sum_horizontal(phys_cols) if phys_cols else pl.lit(0)
        total_true  = pl.sum_horizontal(true_cols) if true_cols else pl.lit(0)
        total_tank  = pl.sum_horizontal(tank_cols) if tank_cols else pl.lit(0)
        total_heal  = pl.sum_horizontal(heal_cols) if heal_cols else pl.lit(0)
        total_cc    = pl.sum_horizontal(cc_cols) if cc_cols else pl.lit(0)

        df = df.with_columns([
            total_magic.fill_null(0).alias(f"{side}_total_magic_dmg"),
            total_phys.fill_null(0).alias(f"{side}_total_phys_dmg"),
            total_true.fill_null(0).alias(f"{side}_total_true_dmg"),
            total_tank.fill_null(0).alias(f"{side}_total_tankiness"),
            total_heal.fill_null(0).alias(f"{side}_total_sustain"),
            total_cc.fill_null(0).alias(f"{side}_total_cc")
        ])

        total_dmg = pl.col(f"{side}_total_magic_dmg") + pl.col(f"{side}_total_phys_dmg") + pl.col(f"{side}_total_true_dmg") + 1
        df = df.with_columns((pl.col(f"{side}_total_magic_dmg") / total_dmg).alias(f"{side}_magic_dmg_ratio"))

    df = df.with_columns([
        ((pl.col("blue_total_magic_dmg") + pl.col("blue_total_true_dmg")) / (pl.col("red_total_tankiness") + 1)).alias("blue_shred_efficiency"),
        ((pl.col("red_total_magic_dmg") + pl.col("red_total_true_dmg")) / (pl.col("blue_total_tankiness") + 1)).alias("red_shred_efficiency"),
        ((pl.col("blue_total_phys_dmg") + pl.col("blue_total_magic_dmg")) / (pl.col("red_total_sustain") + 1000)).alias("blue_anti_sustain_burst"),
        ((pl.col("red_total_phys_dmg") + pl.col("red_total_magic_dmg")) / (pl.col("blue_total_sustain") + 1000)).alias("red_anti_sustain_burst")
    ])
    return df

def enrich_behavioral_strategy(df):
    print("🔬 Calculando Psicología y Riesgo...")
    sides = ["blue", "red"]
    for side in sides:
        jg_aggro = pl.col(f"{side}_JUNGLE_z_style_gank_heaviness").fill_null(0)
        lanes_aggro = (pl.col(f"{side}_TOP_z_style_lane_dominance").fill_null(0) +
                       pl.col(f"{side}_MIDDLE_z_style_lane_dominance").fill_null(0) +
                       pl.col(f"{side}_BOTTOM_z_style_lane_dominance").fill_null(0)) / 3
        df = df.with_columns((jg_aggro * lanes_aggro).alias(f"{side}_strat_gank_compatibility"))

        gold_hunger = sum([pl.col(f"{side}_{role}_z_style_gold_hunger").fill_null(0)
                           for role in ["TOP", "JUNGLE", "MIDDLE", "BOTTOM", "UTILITY"]])
        df = df.with_columns(gold_hunger.alias(f"{side}_strat_resource_friction"))

        invade_potential = pl.col(f"{side}_JUNGLE_z_style_invade_pressure").fill_null(0)
        backup_potential = (pl.col(f"{side}_TOP_z_style_roaming_tendency").fill_null(0) + pl.col(f"{side}_MIDDLE_z_style_roaming_tendency").fill_null(0))
        df = df.with_columns((invade_potential * backup_potential).alias(f"{side}_strat_invade_safety"))

    try:
        blue_vol = sum([pl.col(f"blue_{role}_var_gold_volatility").fill_null(0) for role in ["TOP", "JUNGLE", "MIDDLE", "BOTTOM", "UTILITY"]])
        red_vol  = sum([pl.col(f"red_{role}_var_gold_volatility").fill_null(0)  for role in ["TOP", "JUNGLE", "MIDDLE", "BOTTOM", "UTILITY"]])
        df = df.with_columns((blue_vol - red_vol).alias("diff_team_volatility"))
    except: pass
    return df

def enrich_critical_synergies(df):
    print("🕸️  Calculando Sinergias...")
    try: synergy_matrix = pl.read_parquet("draft_oracle_synergy_matrix.parquet")
    except: return df
    critical_pairs = [("MIDDLE", "JUNGLE", "syn_mid_jg"), ("BOTTOM", "UTILITY", "syn_bot_duo"), ("TOP", "JUNGLE", "syn_top_jg")]
    sides = ["blue", "red"]
    for side in sides:
        for role1, role2, feat_name in critical_pairs:
            col_id1 = f"{side}_{role1}_champ_id"
            col_id2 = f"{side}_{role2}_champ_id"
            if col_id1 not in df.columns or col_id2 not in df.columns: continue
            temp_syn = synergy_matrix.select([pl.col("champ_id").alias(col_id1), pl.col("champ_id_right").alias(col_id2), pl.col("syn_winrate").alias(f"{side}_{feat_name}")])
            df = df.join(temp_syn, on=[col_id1, col_id2], how="left")
            df = df.with_columns(pl.col(f"{side}_{feat_name}").fill_null(0.5))
    if "blue_syn_mid_jg" in df.columns and "red_syn_mid_jg" in df.columns:
        df = df.with_columns((pl.col("blue_syn_mid_jg") - pl.col("red_syn_mid_jg")).alias("gap_syn_mid_jg"))
    return df

# 2. CARGA DE DATOS (REPLICANDO V12)
TRAIN_FILE = "draft_oracle_training_set.parquet"
if not os.path.exists(TRAIN_FILE): raise FileNotFoundError("Ejecuta ML2 primero para generar el dataset.")
df = pl.read_parquet(TRAIN_FILE)

# Aplicar Pipelines
df = enrich_combat_logic(df)
df = enrich_behavioral_strategy(df)
df = enrich_critical_synergies(df)

# Duelos
roles = ["TOP", "JUNGLE", "MIDDLE", "BOTTOM", "UTILITY"]
duel_stats = ["stat_winrate", "stat_gpm", "stat_dpm", "z_style_lane_dominance"]
new_cols = []
for role in roles:
    for stat in duel_stats:
        col_blue, col_red = f"blue_{role}_{stat}", f"red_{role}_{stat}"
        if col_blue in df.columns and col_red in df.columns:
            new_cols.append((pl.col(col_blue) - pl.col(col_red)).alias(f"duel_{role}_{stat}"))
if new_cols: df = df.with_columns(new_cols)

# Features Finales
feature_cols = [c for c in df.columns if (
    "stat_" in c or "rune_" in c or "archetype_" in c or "gap_" in c or "duel_" in c or
    "_total_" in c or "_ratio" in c or "_efficiency" in c or "_burst" in c or
    "z_style_" in c or "_strat_" in c or "_syn_" in c or "diff_team_volatility" in c
) and c not in ["target", "split_key", "game_id"] and "win" not in c]

# Split
print("✂️  Preparando Matrices para Optuna...")
df = df.with_columns(pl.Series(name="split_key", values=np.random.rand(df.height)))
train_data = df.filter(pl.col("split_key") < 0.9)
test_data = df.filter(pl.col("split_key") >= 0.9)

dtrain = xgb.QuantileDMatrix(train_data.select(feature_cols), label=train_data.select("target"))
dtest  = xgb.QuantileDMatrix(test_data.select(feature_cols), label=test_data.select("target"), ref=dtrain)

del df, train_data, test_data
gc.collect()

# 3. FUNCIÓN OBJETIVO OPTUNA
def objective(trial):
    params = {
        'device': 'cuda', # Usar GPU
        'tree_method': 'hist',
        'objective': 'binary:logistic',
        'eval_metric': 'auc',
        'nthread': -1,

        # Espacio de Búsqueda
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 6, 14),
        'subsample': trial.suggest_float('subsample', 0.5, 0.95),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 0.95),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 15),
        'gamma': trial.suggest_float('gamma', 0.0, 5.0),
        'lambda': trial.suggest_float('lambda', 1e-3, 10.0, log=True),
        'alpha': trial.suggest_float('alpha', 1e-3, 10.0, log=True),
    }

    # Entrenamos (con early stopping aquí para descartar rápido los malos)
    model = xgb.train(
        params,
        dtrain,
        num_boost_round=10000,
        evals=[(dtest, "Test")],
        early_stopping_rounds=1000,
        verbose_eval=False
    )

    return model.best_score

# 4. EJECUTAR
print("🚀 Iniciando Optimización (100 Rondas)...")
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=200)

print(f"🏆 MEJORES PARÁMETROS: {study.best_params}")
# Guardar en archivo para usar luego
with open("best_hyperparameters.json", "w") as f:
    json.dump(study.best_params, f)
# Out:
# 🧠 Calculando Lógica de Combate...
# 🔬 Calculando Psicología y Riesgo...
# 🕸️  Calculando Sinergias...
# ✂️  Preparando Matrices para Optuna...
# [I 2026-01-24 21:55:19,016] A new study created in memory with name: no-name-1e7dfc20-8740-4a32-9b7f-9aecdedf0fc4
# 🚀 Iniciando Optimización (100 Rondas)...
# [I 2026-01-24 21:56:09,186] Trial 0 finished with value: 0.5352513104179047 and parameters: {'learning_rate': 0.018191586467461475, 'max_depth': 10, 'subsample': 0.9131602629258304, 'colsample_bytree': 0.7228424503796795, 'min_child_weight': 6, 'gamma': 1.5006341257967044, 'lambda': 0.08386470066926502, 'alpha': 2.0921539742806177}. Best is trial 0 with value: 0.5352513104179047.
# [I 2026-01-24 21:57:00,442] Trial 1 finished with value: 0.5367184032554319 and parameters: {'learning_rate': 0.009349384996345446, 'max_depth': 9, 'subsample': 0.8285714717482899, 'colsample_bytree': 0.707892224073092, 'min_child_weight': 4, 'gamma': 3.7116808129618706, 'lambda': 0.0013668958684538485, 'alpha': 1.7157444794972236}. Best is trial 1 with value: 0.5367184032554319.
# [I 2026-01-24 21:57:59,074] Trial 2 finished with value: 0.5306464604559598 and parameters: {'learning_rate': 0.04477104754783693, 'max_depth': 11, 'subsample': 0.5683100642266281, 'colsample_bytree': 0.9313271613185797, 'min_child_weight': 10, 'gamma': 1.0249303856609704, 'lambda': 8.792564884100893, 'alpha': 3.553773793011962}. Best is trial 1 with value: 0.5367184032554319.
# [I 2026-01-24 21:58:59,639] Trial 3 finished with value: 0.5361315526331205 and parameters: {'learning_rate': 0.009332597598269134, 'max_depth': 8, 'subsample': 0.6135478645643038, 'colsample_bytree': 0.6862091729948203, 'min_child_weight': 3, 'gamma': 0.4193092196772713, 'lambda': 0.4901174095552277, 'alpha': 0.08869894712474084}. Best is trial 1 with value: 0.5367184032554319.
# [I 2026-01-24 21:59:42,016] Trial 4 finished with value: 0.5320602579324478 and parameters: {'learning_rate': 0.051739273462670286, 'max_depth': 9, 'subsample': 0.5916736108407961, 'colsample_bytree': 0.6389517488089397, 'min_child_weight': 13, 'gamma': 2.1766125935947644, 'lambda': 0.007178795629166536, 'alpha': 0.005259776113438194}. Best is trial 1 with value: 0.5367184032554319.
# [I 2026-01-24 22:00:04,274] Trial 5 finished with value: 0.5346927197949244 and parameters: {'learning_rate': 0.02024382401169172, 'max_depth': 9, 'subsample': 0.9101863590992383, 'colsample_bytree': 0.5896274312634786, 'min_child_weight': 2, 'gamma': 4.4243975888749345, 'lambda': 0.005115672605324481, 'alpha': 0.001510389462180715}. Best is trial 1 with value: 0.5367184032554319.
# [I 2026-01-24 22:00:40,167] Trial 6 finished with value: 0.5348761470814183 and parameters: {'learning_rate': 0.02659757483441753, 'max_depth': 7, 'subsample': 0.7167426580234558, 'colsample_bytree': 0.5409334099281481, 'min_child_weight': 2, 'gamma': 3.513453575398384, 'lambda': 0.030356167958479032, 'alpha': 4.261431397820614}. Best is trial 1 with value: 0.5367184032554319.
# [I 2026-01-24 22:02:24,245] Trial 7 finished with value: 0.5336309003989975 and parameters: {'learning_rate': 0.00719214644725177, 'max_depth': 14, 'subsample': 0.8708061380885218, 'colsample_bytree': 0.5780688946056823, 'min_child_weight': 12, 'gamma': 0.42292078605554617, 'lambda': 0.12818213823012764, 'alpha': 0.6190714596865035}. Best is trial 1 with value: 0.5367184032554319.
# [I 2026-01-24 22:02:51,936] Trial 8 finished with value: 0.5320860239539992 and parameters: {'learning_rate': 0.054417432320364424, 'max_depth': 8, 'subsample': 0.574030298470428, 'colsample_bytree': 0.8153967732004013, 'min_child_weight': 6, 'gamma': 0.5555719873051918, 'lambda': 0.5241585986281534, 'alpha': 0.02131621317037432}. Best is trial 1 with value: 0.5367184032554319.
# [I 2026-01-24 22:03:42,147] Trial 9 finished with value: 0.535485597728095 and parameters: {'learning_rate': 0.013866715421416457, 'max_depth': 7, 'subsample': 0.5127592729098014, 'colsample_bytree': 0.532006003902089, 'min_child_weight': 9, 'gamma': 2.3916610523989226, 'lambda': 0.023860106186823066, 'alpha': 1.5887351082636856}. Best is trial 1 with value: 0.5367184032554319.
# [I 2026-01-24 22:03:58,743] Trial 10 finished with value: 0.520556342981948 and parameters: {'learning_rate': 0.1541118908461732, 'max_depth': 12, 'subsample': 0.7876601725488048, 'colsample_bytree': 0.8240100276095914, 'min_child_weight': 5, 'gamma': 4.747377983360954, 'lambda': 0.0010404775910718925, 'alpha': 0.22914233132715123}. Best is trial 1 with value: 0.5367184032554319.
# [I 2026-01-24 22:05:04,745] Trial 11 finished with value: 0.5378638597472372 and parameters: {'learning_rate': 0.00521122974536652, 'max_depth': 6, 'subsample': 0.6960009172011745, 'colsample_bytree': 0.699066607198975, 'min_child_weight': 1, 'gamma': 3.5338018491679097, 'lambda': 1.1832470987735515, 'alpha': 0.04456256284978843}. Best is trial 11 with value: 0.5378638597472372.
# [I 2026-01-24 22:06:45,660] Trial 12 finished with value: 0.5350257364902273 and parameters: {'learning_rate': 0.005190667114855917, 'max_depth': 13, 'subsample': 0.7279544168629288, 'colsample_bytree': 0.7957335085062593, 'min_child_weight': 1, 'gamma': 3.4445343083647435, 'lambda': 7.121718503946208, 'alpha': 0.0431679170669679}. Best is trial 11 with value: 0.5378638597472372.
# [I 2026-01-24 22:08:07,781] Trial 13 finished with value: 0.5376146848029372 and parameters: {'learning_rate': 0.005124647893305396, 'max_depth': 6, 'subsample': 0.8102048979426568, 'colsample_bytree': 0.6598479756599736, 'min_child_weight': 4, 'gamma': 3.4871595075894475, 'lambda': 1.2480454644501586, 'alpha': 0.31355232847236725}. Best is trial 11 with value: 0.5378638597472372.
# [I 2026-01-24 22:09:40,065] Trial 14 finished with value: 0.53819311524492 and parameters: {'learning_rate': 0.005279616409802864, 'max_depth': 6, 'subsample': 0.6963883175116564, 'colsample_bytree': 0.6630725789017757, 'min_child_weight': 15, 'gamma': 2.9742497410643387, 'lambda': 1.9850748727385525, 'alpha': 0.25484037629362827}. Best is trial 14 with value: 0.53819311524492.
# [I 2026-01-24 22:10:00,441] Trial 15 finished with value: 0.53286893653133 and parameters: {'learning_rate': 0.11726425029262501, 'max_depth': 6, 'subsample': 0.6843064996492575, 'colsample_bytree': 0.7698964624477367, 'min_child_weight': 15, 'gamma': 2.853489128368293, 'lambda': 1.7308739153181882, 'alpha': 0.016048612020331317}. Best is trial 14 with value: 0.53819311524492.
# [I 2026-01-24 22:10:49,630] Trial 16 finished with value: 0.53761923295522 and parameters: {'learning_rate': 0.012299670087723343, 'max_depth': 6, 'subsample': 0.6554346992046943, 'colsample_bytree': 0.8977931223104416, 'min_child_weight': 15, 'gamma': 4.190759744014697, 'lambda': 1.5597830670826123, 'alpha': 0.10199132059192327}. Best is trial 14 with value: 0.53819311524492.
# [I 2026-01-24 22:11:52,346] Trial 17 finished with value: 0.5374601443820441 and parameters: {'learning_rate': 0.008010181613242667, 'max_depth': 7, 'subsample': 0.7555237069540882, 'colsample_bytree': 0.6243167856711515, 'min_child_weight': 8, 'gamma': 2.9410114427091147, 'lambda': 0.3054117620215878, 'alpha': 0.006322651645285214}. Best is trial 14 with value: 0.53819311524492.
# [I 2026-01-24 22:13:03,521] Trial 18 finished with value: 0.5373065809108293 and parameters: {'learning_rate': 0.005790604430573154, 'max_depth': 8, 'subsample': 0.6525115169757598, 'colsample_bytree': 0.7544603038973783, 'min_child_weight': 11, 'gamma': 1.9800000339088033, 'lambda': 3.732477377847589, 'alpha': 0.7228298001299315}. Best is trial 14 with value: 0.53819311524492.
# [I 2026-01-24 22:13:22,697] Trial 19 finished with value: 0.5337532032397274 and parameters: {'learning_rate': 0.08857962390998528, 'max_depth': 6, 'subsample': 0.6933252601839821, 'colsample_bytree': 0.5053841028366923, 'min_child_weight': 8, 'gamma': 2.951109102099183, 'lambda': 2.4324921320300126, 'alpha': 0.13361887863937028}. Best is trial 14 with value: 0.53819311524492.
# [I 2026-01-24 22:14:07,949] Trial 20 finished with value: 0.5363353791683845 and parameters: {'learning_rate': 0.012837772590053519, 'max_depth': 11, 'subsample': 0.7595683389485927, 'colsample_bytree': 0.8592223403108263, 'min_child_weight': 14, 'gamma': 3.9415582138904224, 'lambda': 0.17120476732690035, 'alpha': 9.378415226018852}. Best is trial 14 with value: 0.53819311524492.
# [I 2026-01-24 22:14:57,533] Trial 21 finished with value: 0.5370425804912827 and parameters: {'learning_rate': 0.01231254273651413, 'max_depth': 6, 'subsample': 0.6421410562015065, 'colsample_bytree': 0.9438392456276345, 'min_child_weight': 15, 'gamma': 4.4457730204104315, 'lambda': 0.9352105739933347, 'alpha': 0.061588664134905484}. Best is trial 14 with value: 0.53819311524492.
# [I 2026-01-24 22:16:04,175] Trial 22 finished with value: 0.5374042876067232 and parameters: {'learning_rate': 0.007195476109895086, 'max_depth': 7, 'subsample': 0.6567153070651354, 'colsample_bytree': 0.8993785632025607, 'min_child_weight': 13, 'gamma': 4.081417364028634, 'lambda': 3.446067778984315, 'alpha': 0.029609965249718952}. Best is trial 14 with value: 0.53819311524492.
# [I 2026-01-24 22:16:51,150] Trial 23 finished with value: 0.5380274958862913 and parameters: {'learning_rate': 0.011152615860885626, 'max_depth': 6, 'subsample': 0.5208828047576091, 'colsample_bytree': 0.6841595198676393, 'min_child_weight': 12, 'gamma': 4.846844804741174, 'lambda': 0.7847414642723057, 'alpha': 0.19975385771883766}. Best is trial 14 with value: 0.53819311524492.
# [I 2026-01-24 22:17:45,982] Trial 24 finished with value: 0.5364663496520865 and parameters: {'learning_rate': 0.006987992336969205, 'max_depth': 7, 'subsample': 0.5093637106660701, 'colsample_bytree': 0.6863892129986693, 'min_child_weight': 12, 'gamma': 3.1169049946207843, 'lambda': 0.7203735660993551, 'alpha': 0.3466271224397025}. Best is trial 14 with value: 0.53819311524492.
# [I 2026-01-24 22:18:36,152] Trial 25 finished with value: 0.5363564369492605 and parameters: {'learning_rate': 0.01019276466524464, 'max_depth': 8, 'subsample': 0.550264858913173, 'colsample_bytree': 0.6067485458058162, 'min_child_weight': 13, 'gamma': 4.95448442302542, 'lambda': 0.29284440613595175, 'alpha': 0.1863970273201167}. Best is trial 14 with value: 0.53819311524492.
# [I 2026-01-24 22:19:11,127] Trial 26 finished with value: 0.5370566518505113 and parameters: {'learning_rate': 0.017588650382090346, 'max_depth': 6, 'subsample': 0.8579309973961304, 'colsample_bytree': 0.65321509287697, 'min_child_weight': 11, 'gamma': 2.6198435920632877, 'lambda': 3.676779163997943, 'alpha': 0.010452523416729273}. Best is trial 14 with value: 0.53819311524492.
# [I 2026-01-24 22:20:15,900] Trial 27 finished with value: 0.5375276565305952 and parameters: {'learning_rate': 0.006313863621667727, 'max_depth': 7, 'subsample': 0.6109466609312434, 'colsample_bytree': 0.7335723213733645, 'min_child_weight': 7, 'gamma': 1.9889728126553523, 'lambda': 0.06099448264842251, 'alpha': 0.6359613348487345}. Best is trial 14 with value: 0.53819311524492.
# [I 2026-01-24 22:21:41,903] Trial 28 finished with value: 0.5368360606007538 and parameters: {'learning_rate': 0.005179387485650929, 'max_depth': 10, 'subsample': 0.7425489168413703, 'colsample_bytree': 0.696937598987628, 'min_child_weight': 10, 'gamma': 1.664836218979348, 'lambda': 0.3040710057163169, 'alpha': 0.03950997690295387}. Best is trial 14 with value: 0.53819311524492.
# [I 2026-01-24 22:22:23,164] Trial 29 finished with value: 0.5339867118049162 and parameters: {'learning_rate': 0.021904141430820076, 'max_depth': 10, 'subsample': 0.6909245573455904, 'colsample_bytree': 0.7300817770843465, 'min_child_weight': 14, 'gamma': 3.2386504636665974, 'lambda': 0.06907175724234671, 'alpha': 0.0023428636342102092}. Best is trial 14 with value: 0.53819311524492.
# [I 2026-01-24 22:22:58,114] Trial 30 finished with value: 0.5339315587148376 and parameters: {'learning_rate': 0.03756384487853566, 'max_depth': 8, 'subsample': 0.5411577559259052, 'colsample_bytree': 0.6618131938992537, 'min_child_weight': 14, 'gamma': 3.785937121667984, 'lambda': 5.5854171103028305, 'alpha': 0.06500105069194594}. Best is trial 14 with value: 0.53819311524492.
# [I 2026-01-24 22:23:30,114] Trial 31 finished with value: 0.5366746357925736 and parameters: {'learning_rate': 0.0164745510777497, 'max_depth': 6, 'subsample': 0.6672248686785061, 'colsample_bytree': 0.7631732694034266, 'min_child_weight': 15, 'gamma': 4.356436149452363, 'lambda': 1.44019210069868, 'alpha': 0.10848000572342763}. Best is trial 14 with value: 0.53819311524492.
# [I 2026-01-24 22:24:17,456] Trial 32 finished with value: 0.5385213281156355 and parameters: {'learning_rate': 0.011105460933218876, 'max_depth': 6, 'subsample': 0.6297426660240419, 'colsample_bytree': 0.7085818033469734, 'min_child_weight': 12, 'gamma': 4.1493161523713775, 'lambda': 1.7853264523232992, 'alpha': 0.1587373812080323}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 22:25:14,042] Trial 33 finished with value: 0.5371468320463345 and parameters: {'learning_rate': 0.009457757708280006, 'max_depth': 7, 'subsample': 0.6234452466571959, 'colsample_bytree': 0.7139400548014581, 'min_child_weight': 10, 'gamma': 4.834211123382283, 'lambda': 0.7604653293287924, 'alpha': 1.0684585576685721}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 22:26:18,114] Trial 34 finished with value: 0.5378050422162591 and parameters: {'learning_rate': 0.00868913289268661, 'max_depth': 6, 'subsample': 0.7044090606517845, 'colsample_bytree': 0.6747941762900128, 'min_child_weight': 12, 'gamma': 3.809063103907415, 'lambda': 1.9732297517435036, 'alpha': 0.3331057934564727}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 22:27:18,881] Trial 35 finished with value: 0.5370222867952991 and parameters: {'learning_rate': 0.01057014836177331, 'max_depth': 7, 'subsample': 0.6022031957930898, 'colsample_bytree': 0.7101057964254166, 'min_child_weight': 9, 'gamma': 2.592365281428949, 'lambda': 9.756733180866581, 'alpha': 0.1892897044243398}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 22:27:45,582] Trial 36 finished with value: 0.5336947873957419 and parameters: {'learning_rate': 0.030082657145491565, 'max_depth': 9, 'subsample': 0.575498107113174, 'colsample_bytree': 0.6267974800977476, 'min_child_weight': 11, 'gamma': 4.651383081142701, 'lambda': 0.5424582353770392, 'alpha': 0.38216105261056627}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 22:28:24,717] Trial 37 finished with value: 0.5358509528651124 and parameters: {'learning_rate': 0.014755868077250144, 'max_depth': 9, 'subsample': 0.6227838191467311, 'colsample_bytree': 0.7431633893235006, 'min_child_weight': 6, 'gamma': 4.526867482298965, 'lambda': 3.044107116004942, 'alpha': 0.06524497508359854}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 22:29:30,854] Trial 38 finished with value: 0.5358727336825748 and parameters: {'learning_rate': 0.006441736096236126, 'max_depth': 11, 'subsample': 0.7796364068023056, 'colsample_bytree': 0.7820292272723831, 'min_child_weight': 13, 'gamma': 4.1624343538887985, 'lambda': 0.9933784557810538, 'alpha': 2.4875212457690026}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 22:30:20,630] Trial 39 finished with value: 0.5377430158805762 and parameters: {'learning_rate': 0.008070021179460802, 'max_depth': 6, 'subsample': 0.5309753233586743, 'colsample_bytree': 0.5977331297549483, 'min_child_weight': 1, 'gamma': 3.6330992995270517, 'lambda': 6.10300859896892, 'alpha': 0.1641855154614974}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 22:30:53,604] Trial 40 finished with value: 0.5351961602598478 and parameters: {'learning_rate': 0.023223301887905178, 'max_depth': 8, 'subsample': 0.7189865644365906, 'colsample_bytree': 0.5672808014810927, 'min_child_weight': 3, 'gamma': 3.2641025458700614, 'lambda': 0.20234482779444019, 'alpha': 0.016388810066293388}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 22
. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:10:58,280] Trial 80 finished with value: 0.5288606427704009 and parameters: {'learning_rate': 0.17056093765014368, 'max_depth': 7, 'subsample': 0.7096926791169631, 'colsample_bytree': 0.8414165726498783, 'min_child_weight': 1, 'gamma': 2.9815658246721046, 'lambda': 0.30611184351187015, 'alpha': 0.0010369388339093067}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:12:14,008] Trial 81 finished with value: 0.5375360239345306 and parameters: {'learning_rate': 0.005357103699711981, 'max_depth': 6, 'subsample': 0.6798516042661946, 'colsample_bytree': 0.7903101179665833, 'min_child_weight': 8, 'gamma': 4.8019373543741874, 'lambda': 0.4327570561385471, 'alpha': 0.07528511068361023}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:13:28,861] Trial 82 finished with value: 0.5378235221635308 and parameters: {'learning_rate': 0.006078826368530755, 'max_depth': 6, 'subsample': 0.676346586253904, 'colsample_bytree': 0.6808025361157459, 'min_child_weight': 9, 'gamma': 4.872668648789832, 'lambda': 0.3720528601773313, 'alpha': 0.1267279273345444}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:14:58,749] Trial 83 finished with value: 0.5379509349319286 and parameters: {'learning_rate': 0.005333623133238948, 'max_depth': 6, 'subsample': 0.6904180453314798, 'colsample_bytree': 0.7934418189888967, 'min_child_weight': 13, 'gamma': 4.6496559203289305, 'lambda': 0.2563050279222843, 'alpha': 0.7518492811127933}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:16:07,898] Trial 84 finished with value: 0.5376893968243257 and parameters: {'learning_rate': 0.00635120185896938, 'max_depth': 6, 'subsample': 0.7404481603227074, 'colsample_bytree': 0.7010231716363169, 'min_child_weight': 14, 'gamma': 4.381206985241206, 'lambda': 0.8870293937884873, 'alpha': 1.2697217386755981}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:17:04,001] Trial 85 finished with value: 0.5378589269136885 and parameters: {'learning_rate': 0.008318955047010385, 'max_depth': 7, 'subsample': 0.6907100182794588, 'colsample_bytree': 0.728814921289544, 'min_child_weight': 13, 'gamma': 4.1292758190290515, 'lambda': 0.22474719327172013, 'alpha': 0.7818350278351954}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:17:56,074] Trial 86 finished with value: 0.5373786998520999 and parameters: {'learning_rate': 0.009829813851263467, 'max_depth': 7, 'subsample': 0.6917591676301159, 'colsample_bytree': 0.7336586328349085, 'min_child_weight': 13, 'gamma': 4.07216579636631, 'lambda': 1.2217827236489627, 'alpha': 3.950663301268439}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:18:32,705] Trial 87 finished with value: 0.5362752774118393 and parameters: {'learning_rate': 0.013540524838703256, 'max_depth': 8, 'subsample': 0.7102993715562006, 'colsample_bytree': 0.6376602870414932, 'min_child_weight': 13, 'gamma': 3.516049844525774, 'lambda': 0.2572738219622257, 'alpha': 0.7362949100170195}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:19:21,485] Trial 88 finished with value: 0.5376923083220158 and parameters: {'learning_rate': 0.011660375042130027, 'max_depth': 7, 'subsample': 0.7238607867835551, 'colsample_bytree': 0.6662584661455733, 'min_child_weight': 14, 'gamma': 3.828265379800607, 'lambda': 2.143797459793467, 'alpha': 0.3830604732231088}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:20:22,395] Trial 89 finished with value: 0.5375505655900628 and parameters: {'learning_rate': 0.008412041091838528, 'max_depth': 7, 'subsample': 0.6994613692600657, 'colsample_bytree': 0.7087074450639262, 'min_child_weight': 11, 'gamma': 4.12815818971543, 'lambda': 1.7545507669207243, 'alpha': 2.4939373808713214}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:21:30,587] Trial 90 finished with value: 0.5373637887618155 and parameters: {'learning_rate': 0.0078188776149174, 'max_depth': 6, 'subsample': 0.5169910349726651, 'colsample_bytree': 0.6508991309730353, 'min_child_weight': 15, 'gamma': 4.570068555108656, 'lambda': 0.11110496250487198, 'alpha': 5.201730446480471}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:22:27,336] Trial 91 finished with value: 0.5371132738835334 and parameters: {'learning_rate': 0.006974591006001716, 'max_depth': 6, 'subsample': 0.6432440706772684, 'colsample_bytree': 0.7737582412046738, 'min_child_weight': 12, 'gamma': 4.700940969194284, 'lambda': 0.15269981874570623, 'alpha': 0.5568893394466552}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:22:54,501] Trial 92 finished with value: 0.5363058683685353 and parameters: {'learning_rate': 0.04096436391146764, 'max_depth': 6, 'subsample': 0.6648092772119419, 'colsample_bytree': 0.7594458902283044, 'min_child_weight': 13, 'gamma': 4.1961322281220985, 'lambda': 0.07280379876330409, 'alpha': 0.29770963225288527}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:24:29,302] Trial 93 finished with value: 0.5372604109492729 and parameters: {'learning_rate': 0.005577659977378484, 'max_depth': 6, 'subsample': 0.6506839376691511, 'colsample_bytree': 0.8147764018379632, 'min_child_weight': 14, 'gamma': 4.477208451589605, 'lambda': 0.1271489438930551, 'alpha': 0.2156187381363718}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:26:00,373] Trial 94 finished with value: 0.5374024691667763 and parameters: {'learning_rate': 0.005005828079781277, 'max_depth': 6, 'subsample': 0.7197460656783163, 'colsample_bytree': 0.6888837026189055, 'min_child_weight': 11, 'gamma': 3.8922692967420844, 'lambda': 0.1908453533658489, 'alpha': 0.7557510915209897}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:27:05,472] Trial 95 finished with value: 0.5373478872345525 and parameters: {'learning_rate': 0.006093867719602132, 'max_depth': 7, 'subsample': 0.6294170896573396, 'colsample_bytree': 0.8005205934123513, 'min_child_weight': 12, 'gamma': 4.294913305979489, 'lambda': 0.9003289366295978, 'alpha': 1.584890098954598}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:27:23,400] Trial 96 finished with value: 0.5319645502890464 and parameters: {'learning_rate': 0.08577819242548435, 'max_depth': 9, 'subsample': 0.7496604894791468, 'colsample_bytree': 0.721929007117205, 'min_child_weight': 10, 'gamma': 4.003634899520253, 'lambda': 0.2290671193778135, 'alpha': 0.40828635381768186}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:28:15,281] Trial 97 finished with value: 0.5362604138203088 and parameters: {'learning_rate': 0.010449645998257923, 'max_depth': 10, 'subsample': 0.5536104779858648, 'colsample_bytree': 0.6739692939055139, 'min_child_weight': 14, 'gamma': 4.980966605948045, 'lambda': 3.33818225909206, 'alpha': 0.8539690275072103}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:29:05,720] Trial 98 finished with value: 0.5375528033091334 and parameters: {'learning_rate': 0.00910733084716912, 'max_depth': 6, 'subsample': 0.5703926928721668, 'colsample_bytree': 0.7022498745935518, 'min_child_weight': 13, 'gamma': 3.715828460197886, 'lambda': 0.6011336800926176, 'alpha': 0.044324808844445424}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:30:00,373] Trial 99 finished with value: 0.53777673413177 and parameters: {'learning_rate': 0.007144915205335543, 'max_depth': 7, 'subsample': 0.688322529929351, 'colsample_bytree': 0.7407145544073832, 'min_child_weight': 12, 'gamma': 4.621462593666776, 'lambda': 8.025784401553953, 'alpha': 0.17057080965186872}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:30:57,920] Trial 100 finished with value: 0.5363062659506973 and parameters: {'learning_rate': 0.005622173337979172, 'max_depth': 8, 'subsample': 0.8894699311305563, 'colsample_bytree': 0.8213151212936421, 'min_child_weight': 1, 'gamma': 3.5039582916728014, 'lambda': 1.3742324774201093, 'alpha': 0.06925520400320168}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:31:59,796] Trial 101 finished with value: 0.5376356663512453 and parameters: {'learning_rate': 0.006578790125225452, 'max_depth': 6, 'subsample': 0.6856915671068038, 'colsample_bytree': 0.7854279666343867, 'min_child_weight': 7, 'gamma': 4.8098126651149755, 'lambda': 0.34061537785367796, 'alpha': 0.1218797700874425}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:33:06,631] Trial 102 finished with value: 0.5372483990421868 and parameters: {'learning_rate': 0.005350882509431237, 'max_depth': 6, 'subsample': 0.6712964127102711, 'colsample_bytree': 0.6573371847544051, 'min_child_weight': 5, 'gamma': 4.722635293788835, 'lambda': 0.4947406878879132, 'alpha': 0.10360837531655917}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:34:25,517] Trial 103 finished with value: 0.5372770319946961 and parameters: {'learning_rate': 0.005360687746367179, 'max_depth': 6, 'subsample': 0.6800516342409101, 'colsample_bytree': 0.7944988365500418, 'min_child_weight': 6, 'gamma': 4.406652436834813, 'lambda': 0.17303760006447372, 'alpha': 0.14425493310373882}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:35:19,394] Trial 104 finished with value: 0.5373602245960633 and parameters: {'learning_rate': 0.007776791620802879, 'max_depth': 6, 'subsample': 0.6549507212015006, 'colsample_bytree': 0.7718174756933274, 'min_child_weight': 3, 'gamma': 4.899459593700676, 'lambda': 0.2585603386781469, 'alpha': 0.09220791907907482}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:36:46,762] Trial 105 finished with value: 0.5372646629673495 and parameters: {'learning_rate': 0.005994824413130923, 'max_depth': 6, 'subsample': 0.7132612308193403, 'colsample_bytree': 0.8323038209669886, 'min_child_weight': 2, 'gamma': 3.332020630221261, 'lambda': 0.6916449817224488, 'alpha': 0.3092719355069934}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:37:16,807] Trial 106 finished with value: 0.5355907335809346 and parameters: {'learning_rate': 0.0292556501892194, 'max_depth': 7, 'subsample': 0.6984855700163607, 'colsample_bytree': 0.8563656864975554, 'min_child_weight': 8, 'gamma': 4.643190936669571, 'lambda': 2.339524502111295, 'alpha': 0.05520884458686074}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:38:40,140] Trial 107 finished with value: 0.5375880450388767 and parameters: {'learning_rate': 0.005056679511258718, 'max_depth': 6, 'subsample': 0.7360739530204541, 'colsample_bytree': 0.728491845510524, 'min_child_weight': 13, 'gamma': 4.1806075764088195, 'lambda': 1.050281684203051, 'alpha': 0.022707480334792293}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:39:52,753] Trial 108 finished with value: 0.5375980238820169 and parameters: {'learning_rate': 0.00674404496083195, 'max_depth': 6, 'subsample': 0.5425051174175884, 'colsample_bytree': 0.6904165363572141, 'min_child_weight': 11, 'gamma': 4.537441050888804, 'lambda': 0.4301515362927418, 'alpha': 0.4541569707458422}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23
. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:49:55,051] Trial 118 finished with value: 0.5373049811997117 and parameters: {'learning_rate': 0.006998456125536707, 'max_depth': 8, 'subsample': 0.5262548189874787, 'colsample_bytree': 0.8083725628214591, 'min_child_weight': 15, 'gamma': 4.455994733509975, 'lambda': 4.096456439776294, 'alpha': 0.6472720121019468}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:50:55,970] Trial 119 finished with value: 0.5376182348949846 and parameters: {'learning_rate': 0.0076329641561503955, 'max_depth': 7, 'subsample': 0.5092337970806213, 'colsample_bytree': 0.837444733294337, 'min_child_weight': 14, 'gamma': 4.579093042816518, 'lambda': 9.841697343502716, 'alpha': 1.176011461057089}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:52:15,247] Trial 120 finished with value: 0.5375263476760446 and parameters: {'learning_rate': 0.006455809264717333, 'max_depth': 8, 'subsample': 0.5577309638925514, 'colsample_bytree': 0.7982038540685917, 'min_child_weight': 15, 'gamma': 1.5460260252137226, 'lambda': 6.181676624617568, 'alpha': 1.0505047769876565}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:53:18,426] Trial 121 finished with value: 0.5378118351244648 and parameters: {'learning_rate': 0.00587609369366777, 'max_depth': 7, 'subsample': 0.51295607660625, 'colsample_bytree': 0.7671344050177963, 'min_child_weight': 15, 'gamma': 3.16303894872373, 'lambda': 4.656864522751392, 'alpha': 0.5215173217519783}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:54:21,201] Trial 122 finished with value: 0.5368116480004852 and parameters: {'learning_rate': 0.0069474898307422175, 'max_depth': 7, 'subsample': 0.5405607064127752, 'colsample_bytree': 0.8194812525552092, 'min_child_weight': 14, 'gamma': 4.302919165810977, 'lambda': 3.356445262042985, 'alpha': 0.3867560455234965}. Best is trial 32 with value: 0.5385213281156355.
# [I 2026-01-24 23:55:26,417] Trial 123 finished with value: 0.5377084221276601 and parameters: {'learning_rate': 0.005580412326503105, 'max_depth': 7, 'subsample': 0.5953960114718034, 'colsample_bytree': 0.7519357800579182, 'min_child_weight': 15, 'gamma': 4.858197932283916, 'lambda': 1.414293615970902, 'alpha': 1.7286607077107532}. Best is trial 32 with value: 0.5385213281156355.
# ...
# [I 2026-01-25 00:30:06,300] Trial 160 finished with value: 0.5374358842469114 and parameters: {'learning_rate': 0.007211635907443397, 'max_depth': 7, 'subsample': 0.6374062941964362, 'colsample_bytree': 0.7179755568077382, 'min_child_weight': 15, 'gamma': 4.881345526730005, 'lambda': 2.733820989901134, 'alpha': 1.0462056996639453}. Best is trial 125 with value: 0.5388888605720735.
# [I 2026-01-25 00:31:14,021] Trial 161 finished with value: 0.5377095802762881 and parameters: {'learning_rate': 0.006000915883591263, 'max_depth': 6, 'subsample': 0.5279001574812586, 'colsample_bytree': 0.6817853159532837, 'min_child_weight': 14, 'gamma': 4.524668139797431, 'lambda': 9.983465970286527, 'alpha': 0.40119988266013823}. Best is trial 125 with value: 0.5388888605720735.
# [I 2026-01-25 00:31:46,110] Trial 162 finished with value: 0.534574586289255 and parameters: {'learning_rate': 0.024359632959117923, 'max_depth': 7, 'subsample': 0.5494374007102061, 'colsample_bytree': 0.6985654767776822, 'min_child_weight': 9, 'gamma': 4.762033267278006, 'lambda': 5.749056502965301, 'alpha': 0.8619185996086361}. Best is trial 125 with value: 0.5388888605720735.
# [I 2026-01-25
. Best is trial 125 with value: 0.5388888605720735.
# [I 2026-01-25 00:42:20,725] Trial 173 finished with value: 0.5375402032384655 and parameters: {'learning_rate': 0.0065392436214358396, 'max_depth': 6, 'subsample': 0.5287907195178793, 'colsample_bytree': 0.7929922534855538, 'min_child_weight': 15, 'gamma': 4.663360691228755, 'lambda': 5.1405836539038186, 'alpha': 0.17978376162165016}. Best is trial 125 with value: 0.5388888605720735.
# [I 2026-01-25 00:43:26,177] Trial 174 finished with value: 0.5370244213072007 and parameters: {'learning_rate': 0.008393736190814741, 'max_depth': 7, 'subsample': 0.5109073555494227, 'colsample_bytree': 0.862817422654383, 'min_child_weight': 14, 'gamma': 4.782081032084099, 'lambda': 7.127505013083444, 'alpha': 0.3527957276461667}. Best is trial 125 with value: 0.5388888605720735.
# [I 2026-01-25 00:44:25,048] Trial 175 finished with value: 0.5375911570868608 and parameters: {'learning_rate': 0.0069331938741631, 'max_depth': 7, 'subsample': 0.5179022629570103, 'colsample_bytree': 0.5266289485868778, 'min_child_weight': 15, 'gamma': 4.998045900741575, 'lambda': 0.026144173842310874, 'alpha': 0.8719175863622166}. Best is trial 125 with value: 0.5388888605720735.
# [I 2026-01-25 00:45:36,257] Trial 176 finished with value: 0.5343742377183012 and parameters: {'learning_rate': 0.009210055743032783, 'max_depth': 14, 'subsample': 0.5453260149336427, 'colsample_bytree': 0.8046777978499087, 'min_child_weight': 14, 'gamma': 4.453308478190074, 'lambda': 9.835944331100576, 'alpha': 0.6639055184312405}. Best is trial 125 with value: 0.5388888605720735.
# [I 2026-01-25 00:46:34,421] Trial 177 finished with value: 0.5370965707414985 and parameters: {'learning_rate': 0.007572225068381278, 'max_depth': 6, 'subsample': 0.6216250054425396, 'colsample_bytree': 0.706867556066013, 'min_child_weight': 11, 'gamma': 4.04857671838334, 'lambda': 2.2437805030314064, 'alpha': 0.14968537013314592}. Best is trial 125 with value: 0.5388888605720735.
# [I 2026-01-25 00:47:29,581] Trial 178 finished with value: 0.5371354692888843 and parameters: {'learning_rate': 0.01266540243083998, 'max_depth': 8, 'subsample': 0.5329330282653416, 'colsample_bytree': 0.884693711003264, 'min_child_weight': 15, 'gamma': 4.881089098517537, 'lambda': 6.11574671334966, 'alpha': 0.24253258000443065}. Best is trial 125 with value: 0.5388888605720735.
# [I 2026-01-25 00:48:42,590] Trial 179 finished with value: 0.5369145449614455 and parameters: {'learning_rate': 0.00628596745841384, 'max_depth': 7, 'subsample': 0.5002489125948748, 'colsample_bytree': 0.7633941696926183, 'min_child_weight': 13, 'gamma': 2.993853425124499, 'lambda': 4.3826806706009656, 'alpha': 1.4524671084494256}. Best is trial 125 with value: 0.5388888605720735.
# [I 2026-01-25 00:49:39,745] Trial 180 finished with value: 0.5372652962840676 and parameters: {'learning_rate': 0.010595489210369097, 'max_depth': 6, 'subsample': 0.5529487750561514, 'colsample_bytree': 0.6934569253499098, 'min_child_weight': 15, 'gamma': 4.307026407218634, 'lambda': 3.2090718472695117, 'alpha': 1.0998032559452928}. Best is trial 125 with value: 0.5388888605720735.
# [I 2026-01-25 00:50:35,941] Trial 181 finished with value: 0.5375650304266227 and parameters: {'learning_rate': 0.008089200331005481, 'max_depth': 7, 'subsample': 0.5226324564235225, 'colsample_bytree': 0.8127273363405688, 'min_child_weight': 4, 'gamma': 4.899576849036603, 'lambda': 1.6855365161350169, 'alpha': 0.6008881356996795}. Best is trial 125 with value: 0.5388888605720735.
# [I 2026-01-25 00:51:45,853] Trial 182 finished with value: 0.5375506687972317 and parameters: {'learning_rate': 0.00717960043417336, 'max_depth': 7, 'subsample': 0.5346477936943576, 'colsample_bytree': 0.7989518149425754, 'min_child_weight': 14, 'gamma': 4.752512872334817, 'lambda': 1.2423999940494417, 'alpha': 0.08224520808906775}. Best is trial 125 with value: 0.5388888605720735.
# [I 2026-01-25
. Best is trial 125 with value: 0.5388888605720735.
# [I 2026-01-25 01:02:41,240] Trial 192 finished with value: 0.5366679255673839 and parameters: {'learning_rate': 0.0061890465897932135, 'max_depth': 6, 'subsample': 0.5144290494815908, 'colsample_bytree': 0.7672645267337186, 'min_child_weight': 14, 'gamma': 4.696266144527313, 'lambda': 0.00551933478656673, 'alpha': 0.5717216739606698}. Best is trial 125 with value: 0.5388888605720735.
# [I 2026-01-25 01:03:55,515] Trial 193 finished with value: 0.5373080592362425 and parameters: {'learning_rate': 0.005716208356894912, 'max_depth': 7, 'subsample': 0.5418900949361383, 'colsample_bytree': 0.7508965651430896, 'min_child_weight': 13, 'gamma': 4.756597726283704, 'lambda': 6.749801286585736, 'alpha': 0.2784426752881583}. Best is trial 125 with value: 0.5388888605720735.
# [I 2026-01-25 01:05:02,819] Trial 194 finished with value: 0.5378817638454187 and parameters: {'learning_rate': 0.006664879127183952, 'max_depth': 6, 'subsample': 0.5192122753828685, 'colsample_bytree': 0.7280711871497205, 'min_child_weight': 15, 'gamma': 4.940417890216576, 'lambda': 0.0029298992545450774, 'alpha': 0.43300376752153685}. Best is trial 125 with value: 0.5388888605720735.
# [I 2026-01-25 01:06:05,149] Trial 195 finished with value: 0.5378401995037734 and parameters: {'learning_rate': 0.006109122856925888, 'max_depth': 7, 'subsample': 0.5363070629923308, 'colsample_bytree': 0.7421307762985415, 'min_child_weight': 14, 'gamma': 4.591597251018263, 'lambda': 0.008429286217272474, 'alpha': 0.6474084945854429}. Best is trial 125 with value: 0.5388888605720735.
# [I 2026-01-25 01:07:09,087] Trial 196 finished with value: 0.5373299831363708 and parameters: {'learning_rate': 0.006939427451402039, 'max_depth': 6, 'subsample': 0.802233651722911, 'colsample_bytree': 0.7791795922007839, 'min_child_weight': 12, 'gamma': 4.212008303051136, 'lambda': 0.004034793606356487, 'alpha': 0.5373032040852544}. Best is trial 125 with value: 0.5388888605720735.
# [I 2026-01-25 01:08:16,149] Trial 197 finished with value: 0.5365355846566725 and parameters: {'learning_rate': 0.00788592690694596, 'max_depth': 7, 'subsample': 0.5520682879694363, 'colsample_bytree': 0.7709534822137611, 'min_child_weight': 15, 'gamma': 4.830229281904611, 'lambda': 0.0016350334173688618, 'alpha': 0.35993917808644743}. Best is trial 125 with value: 0.5388888605720735.
# [I 2026-01-25 01:09:11,784] Trial 198 finished with value: 0.5381734677665505 and parameters: {'learning_rate': 0.009414016066487996, 'max_depth': 7, 'subsample': 0.5294981089272749, 'colsample_bytree': 0.8456468297687212, 'min_child_weight': 14, 'gamma': 4.475342923806974, 'lambda': 5.17490157048808, 'alpha': 0.7806204476161362}. Best is trial 125 with value: 0.5388888605720735.
# [I 2026-01-25 01:09:53,870] Trial 199 finished with value: 0.5377509651781968 and parameters: {'learning_rate': 0.009477197884050612, 'max_depth': 7, 'subsample': 0.5098517783349923, 'colsample_bytree': 0.880456422431305, 'min_child_weight': 14, 'gamma': 4.726177731510296, 'lambda': 5.363574762371971, 'alpha': 0.7599374196970018}. Best is trial 125 with value: 0.5388888605720735.
# 🏆 MEJORES PARÁMETROS: {'learning_rate': 0.008957827193783819, 'max_depth': 7, 'subsample': 0.5309661926071266, 'colsample_bytree': 0.8548686375385406, 'min_child_weight': 14, 'gamma': 4.997392487608526, 'lambda': 6.9850562385010155, 'alpha': 0.6101433943490518}

# %% [markdown]
# Entrenamiento GPU

# %% [markdown]
# Entrendando los modelos
